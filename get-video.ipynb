# %%
import subprocess
pip install yt-dlp
subprocess.run([
    'yt-dlp', 
    '-f', 'best[height<=480]',
    '--output', 'test_video.mp4',
    'https://youtube.com/shorts/oKzXV0-0qHQ?si=s2xD-yrV8kj_xuZ8'
])
